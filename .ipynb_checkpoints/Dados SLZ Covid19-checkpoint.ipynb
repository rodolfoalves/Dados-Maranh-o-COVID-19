# %% [markdown]
# # Dados São Luís COVID-19 (Dados referentes ao ano de 2020)

# %% [markdown]
# ## Foram utilizados a base de dados abertos da Secretaria de Saúde do Estado do Maranhão para gerar algumas análises referentes ao número de novos casos, novas mortes, mortes mensais, além de alguns gráficos representativos

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Leitura dos dois arquivos .CSV baixados diretamente do site do painel covid BR, do SUS.
# ### https://covid.saude.gov.br

# %%
#df1 = pd.read_csv('2020.csv')

df1 = pd.read_csv('files_from_data/PAINEL_COVIDBR_2020_Parte1.csv', sep = ';')
df2 = pd.read_csv('files_from_data/PAINEL_COVIDBR_2020_Parte2.csv', sep = ';')

# %% [markdown]
# ### Casos Somente no Estado do Maranhão

# %%
dfMA1 = df1.loc[df1['estado'] == 'MA']

dfMA1
# Out:
#          regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1264   Nordeste     MA       NaN     21       NaN             NaN
# 1265   Nordeste     MA       NaN     21       NaN             NaN
# 1266   Nordeste     MA       NaN     21       NaN             NaN
# 1267   Nordeste     MA       NaN     21       NaN             NaN
# 1268   Nordeste     MA       NaN     21       NaN             NaN
# ...         ...    ...       ...    ...       ...             ...
# 89636  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 89637  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 89638  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 89639  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 89640  Nordeste     MA   Zé Doca     21  211400.0         21019.0
#
#       nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 1264              NaN  2020-02-25          9         7075181.0
# 1265              NaN  2020-02-26          9         7075181.0
# 1266              NaN  2020-02-27          9         7075181.0
# 1267              NaN  2020-02-28          9         7075181.0
# 1268              NaN  2020-02-29          9         7075181.0
# ...               ...         ...        ...               ...
# 89636         ZE DOCA  2020-07-27         31           51714.0
# 89637         ZE DOCA  2020-07-28         31           51714.0
# 89638         ZE DOCA  2020-07-29         31           51714.0
# 89639         ZE DOCA  2020-07-30         31           51714.0
# 89640         ZE DOCA  2020-07-31         31           51714.0
#
#        casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 1264                0           0                0            0
# 1265                0           0                0            0
# 1266                0           0                0            0
# 1267                0           0                0            0
# 1268                0           0                0            0
# ...               ...         ...              ...          ...
# 89636            2799          12               35            0
# 89637            2797          -2               35            0
# 89638            2833          36               35            0
# 89639            2841           8               35            0
# 89640            2841           0               36            1
#
#        Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 1264                NaN                    NaN                     NaN
# 1265                NaN                    NaN                     NaN
# 1266                NaN                    NaN                     NaN
# 1267                NaN                    NaN                     NaN
# 1268                NaN                    NaN                     NaN
# ...                 ...                    ...                     ...
# 89636               NaN                    NaN                     0.0
# 89637               NaN                    NaN                     0.0
# 89638               NaN                    NaN                     0.0
# 89639               NaN                    NaN                     0.0
# 89640               NaN                    NaN                     0.0
#
# [27844 rows x 17 columns]

# %%
dfMA2 = df2.loc[df2['estado'] == 'MA']

dfMA2
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1224    Nordeste     MA       NaN     21       NaN             NaN
# 1225    Nordeste     MA       NaN     21       NaN             NaN
# 1226    Nordeste     MA       NaN     21       NaN             NaN
# 1227    Nordeste     MA       NaN     21       NaN             NaN
# 1228    Nordeste     MA       NaN     21       NaN             NaN
# ...          ...    ...       ...    ...       ...             ...
# 106942  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 106943  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 106944  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 106945  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 106946  Nordeste     MA   Zé Doca     21  211400.0         21019.0
#
#        nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 1224               NaN  2020-08-01         31         7075181.0
# 1225               NaN  2020-08-02         32         7075181.0
# 1226               NaN  2020-08-03         32         7075181.0
# 1227               NaN  2020-08-04         32         7075181.0
# 1228               NaN  2020-08-05         32         7075181.0
# ...                ...         ...        ...               ...
# 106942         ZE DOCA  2020-12-27         53           51714.0
# 106943         ZE DOCA  2020-12-28         53           51714.0
# 106944         ZE DOCA  2020-12-29         53           51714.0
# 106945         ZE DOCA  2020-12-30         53           51714.0
# 106946         ZE DOCA  2020-12-31         53           51714.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 1224            121581         920             3032           19
# 1225            121953         372             3050           18
# 1226            122482         529             3069           19
# 1227            123887        1405             3085           16
# 1228            125459        1572             3103           18
# ...                ...         ...              ...          ...
# 106942            3847           0               39            0
# 106943            3847           0               39            0
# 106944            3847           0               39            0
# 106945            3847           0               39            0
# 106946            3847           0               39            0
#
#         Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 1224                 NaN                    NaN                     NaN
# 1225                 NaN                    NaN                     NaN
# 1226                 NaN                    NaN                     NaN
# 1227                 NaN                    NaN                     NaN
# 1228                 NaN                    NaN                     NaN
# ...                  ...                    ...                     ...
# 106942               NaN                    NaN                     0.0
# 106943               NaN                    NaN                     0.0
# 106944               NaN                    NaN                     0.0
# 106945               NaN                    NaN                     0.0
# 106946               NaN                    NaN                     0.0
#
# [33507 rows x 17 columns]

# %%
dfMA = pd.concat([dfMA1, dfMA2], axis = 0)

dfMA
# Out:
#           regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 1264    Nordeste     MA       NaN     21       NaN             NaN
# 1265    Nordeste     MA       NaN     21       NaN             NaN
# 1266    Nordeste     MA       NaN     21       NaN             NaN
# 1267    Nordeste     MA       NaN     21       NaN             NaN
# 1268    Nordeste     MA       NaN     21       NaN             NaN
# ...          ...    ...       ...    ...       ...             ...
# 106942  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 106943  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 106944  Nordeste     MA   Zé Doca     21  211400.0         21019.0
# 85610        SAO LUIS  2020-04-29         18         1101884.0
# 85612        SAO LUIS  2020-05-01         18         1101884.0
# 85616        SAO LUIS  2020-05-05         19         1101884.0
# 85619        SAO LUIS  2020-05-08         19         1101884.0
# 85620        SAO LUIS  2020-05-09         19         1101884.0
# 85621        SAO LUIS  2020-05-10         20         1101884.0
# 85623        SAO LUIS  2020-05-12         20         1101884.0
# 85626        SAO LUIS  2020-05-15         20         1101884.0
# 85627        SAO LUIS  2020-05-16         20         1101884.0
# 85631        SAO LUIS  2020-05-20         21         1101884.0
# 85650        SAO LUIS  2020-06-08         24         1101884.0
# 85669        SAO LUIS  2020-06-27         26         1101884.0
# 85685        SAO LUIS  2020-07-13         29         1101884.0
# 85686        SAO LUIS  2020-07-14         29         1101884.0
# 85688        SAO LUIS  2020-07-16         29         1101884.0
#
#        casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 85609            1977          83              116           18
# 85610            2149         172              136           20
# 85612            2671         239              165           16
# 85616            3088         125              213           16
# 85619            3745         214              255           17
# 85620            4008         263              271           16
# 85621            4274         266              289           18
# 85623            4780         164              324           21
# 85626            5375         335              363           17
# 85627            5597         222              379           16
# 85631            6479         231              434           20
# 85650           10755         261              577           20
# 85669           12816          61              788           17
# 85685           14437         101              980           16
# 85686           14512          75              996           16
# 85688           14734         101             1026           16
#
#        Recuperadosnovos  emAcompanhamentoNovos  interior/metropolitana
# 85609               NaN                    NaN                     1.0
# 85610               NaN                    NaN                     1.0
# 85612               NaN                    NaN                     1.0
# 85616               NaN                    NaN                     1.0
# 85619               NaN                    NaN                     1.0
# 85620               NaN                    NaN                     1.0
# 85621               NaN                    NaN                     1.0
# 85623               NaN                    NaN                     1.0
# 85626               NaN                    NaN                     1.0
# 85627               NaN                    NaN                     1.0
# 85631               NaN                    NaN                     1.0
# 85650               NaN                    NaN                     1.0
# 85669               NaN                    NaN                     1.0
# 85685               NaN                    NaN                     1.0
# 85686               NaN                    NaN                     1.0
# 85688               NaN                    NaN                     1.0

# %% [markdown]
# ### Linha na qual tiveram mais óbitos

# %%
dfMA.loc[dfMA['obitosNovos'] == dfMA['obitosNovos'].max()]
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 1368  Nordeste     MA       NaN     21     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 1368             NaN  2020-06-08         24         7075181.0           49371
#
#       casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# 1368        1778             1247           77               NaN
#
#       emAcompanhamentoNovos  interior/metropolitana
# 1368                    NaN                     NaN

# %% [markdown]
# ### Data na qual tiveram mais óbitos

# %%
dfMA.loc[dfMA['obitosNovos'] == dfMA['obitosNovos'].max(), 'data']
# Out:
# 1368   2020-06-08
# Name: data, dtype: datetime64[ns]

# %% [markdown]
# ### Linha na qual tiveram mais casos

# %%
dfMA.loc[dfMA['casosNovos'] == dfMA['casosNovos'].max()]
# Out:
#         regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 1391  Nordeste     MA       NaN     21     NaN             NaN
#
#      nomeRegiaoSaude       data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 1391             NaN 2020-07-01         27         7075181.0           83256
#
#       casosNovos  obitosAcumulado  obitosNovos  Recuperadosnovos  \
# 1391        2805             2081           33               NaN
#
#       emAcompanhamentoNovos  interior/metropolitana  month
# 1391                    NaN                     NaN      7

# %% [markdown]
# ### Data em que tiveram mais casos

# %%
dfMA.loc[dfMA['casosNovos'] == dfMA['casosNovos'].max(), 'data']
# Out:
# 1391   2020-07-01
# Name: data, dtype: datetime64[ns]

# %% [markdown]
# ### Total de casos do estado do Maranhão

# %%
dfMA['casosNovos'].sum()
# Out:
# 401876

# %% [markdown]
# ### Total de óbitos

# %%
dfMA['obitosNovos'].sum()
# Out:
# 9000

# %%
dfMA.data = dfMA.data.astype('string')
dfMA.dtypes
# Out:
# regiao                     object
# estado                     object
# municipio                  object
# coduf                       int64
# codmun                    float64
# codRegiaoSaude            float64
# nomeRegiaoSaude            object
# data                       string
# semanaEpi                   int64
# populacaoTCU2019          float64
# casosAcumulado              int64
# casosNovos                  int64
# obitosAcumulado             int64
# obitosNovos                 int64
# Recuperadosnovos          float64
# emAcompanhamentoNovos     float64
# interior/metropolitana    float64
# dtype: object

# %%
#dfMA['data'] = pd.to_datetime[dfMA['data']]

dfMA['data'] = dfMA['data'].astype('datetime64[ns]')

# %%
dfMA.dtypes
# Out:
# regiao                            object
# estado                            object
# municipio                         object
# coduf                              int64
# codmun                           float64
# codRegiaoSaude                   float64
# nomeRegiaoSaude                   object
# data                      datetime64[ns]
# semanaEpi                          int64
# populacaoTCU2019                 float64
# casosAcumulado                     int64
# casosNovos                         int64
# obitosAcumulado                    int64
# obitosNovos                        int64
# Recuperadosnovos                 float64
# emAcompanhamentoNovos            float64
# interior/metropolitana           float64
# dtype: object

# %%
dfMA['month'] = dfMA['data'].dt.month

# %%
dfMA.dtypes
# Out:
# regiao                            object
# estado                            object
# municipio                         object
# coduf                              int64
# codmun                           float64
# codRegiaoSaude                   float64
# nomeRegiaoSaude                   object
# data                      datetime64[ns]
# semanaEpi                          int64
# populacaoTCU2019                 float64
# casosAcumulado                     int64
# casosNovos                         int64
# obitosAcumulado                    int64
# obitosNovos                        int64
# Recuperadosnovos                 float64
# emAcompanhamentoNovos            float64
# interior/metropolitana           float64
# month                              int64
# dtype: object

# %%
mortesMensais = []

for i in range (1,13,1):
    mortesMensais.append(
        dfMA.loc[(dfMA['month'] == i) & (dfMA['municipio'] == 'São Luís'), 'obitosNovos'].sum())
    
mortesMensais
# Out:
# [0, 0, 1, 148, 375, 301, 318, 62, 34, 15, 22, 23]

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']

fig = plt.figure()

ax = fig.add_axes([0,1,2,1])
ax.bar(meses,mortesMensais)
plt.show()
